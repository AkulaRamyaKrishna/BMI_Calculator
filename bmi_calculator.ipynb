# %%
import body_metrics

print("\n===============================")
print("       BMI Calculator")
print("===============================\n")

name = input("Enter your name: ")
weight = float(input("Enter your weight in pounds: "))
height = float(input("Enter your height in inches: "))

if weight <= 0 or height <= 0:
    print("Please enter valid positive numbers")
else:
    bmi = body_metrics.calculate_bmi(weight, height)
    category = body_metrics.bmi_category(bmi)

    print(f"\n{name}, your BMI is: {bmi:.2f}")
    print(f"You are classified as: {category}")
# Out:
# ===============================
#        BMI Calculator
# ===============================
# Enter your name:  reer
# Enter your weight in pounds:  242
# Enter your height in inches:  34
# reer, your BMI is: 147.17
# You are classified as: Morbidly Obese
